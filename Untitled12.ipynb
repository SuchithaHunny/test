# %%
import matplotlib.pyplot as plt
import numpy as np
from pywaffle import Waffle
arr=np.array([5,10,15])

fig=plt.figure(FigureClass=Waffle,rows=5,values=arr,icons="star" ,colors=["red","green","blue"],labels=["car","bike","taxi"])
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>
